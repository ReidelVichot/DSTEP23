# %% [markdown]
# <a href="https://colab.research.google.com/github/ReidelVichot/DSTEP23/blob/main/assignments/dstep23_assignment_01_RVichot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DSTEP23 // Assignment #1**
#
# assigned : **Sep 5, 2023**
#
# DUE : **Sep 12, 2023 11:59pm**
#
# ## **Alternative and Nuclear Energy Use Trends**
#
# <img src="https://www.techrepublic.com/wp-content/uploads/2022/09/image-sciline-american-association-for-the-advancement-of-science-aaas.jpg" width=250x>
#
# <img src="https://wbwaterdata.org/uploads/group/2020-07-12-132413.117294world-bank-logo-png-5.png" width=250x>
#
# ---

# %% [markdown]
# ### OVERVIEW
#
# This assignment uses "open data" from the [World Bank](https://data.worldbank.org/) to explore the rate of adoption of alternative and nuclear energy sources globally.  In particular, you will attempt to address the following Problem Statement:
#
# <i>**"How does the rate of adoption of alternative and nuclear energy by the United States over the past ~50 years compare with that of the European Union?"**</i>
#
# <br>
#
# <b>
#
# How to complete and submit assignments:
#
# 1. Please make a copy of this notebook in your Google Drive and add your name to the filename.
#
# 2. Once you have completed the notebook, please share it with me before the due date and time by clicking the "Share" button in the upper right corner of the notebook.
#
#
# Rules for assignments:
#
# 1. You may work with other students in the class, but if you do, each student with whom you worked <u>must</u> be listed below.  Direct copying from someone else's notebook is not permitted.
#
# 2. You may use generative AI models (e.g., ChatGPT) to help complete the assignment but if you do you must answer YES to the question below and bear in mind that such models <u>often</u> yield incorrect and biased solutions.
#
# 3. All solutions and outputs must be derived with python and the notebook should be "runable" by me (top to bottom) without errors.
#
# 4. Late assignments will assess a 15% late penalty up to 3 days after the due date and a 50% late penalty until the end of the term.
#
# </b>
#
# <u>**Instructions for tasks that will be graded are in bold below.**</u>
#
# ---

# %% [markdown]
# **Please list the names of the other students with whom you worked for this assignment (if none, put "None").**

# %% [markdown]
# None

# %% [markdown]
# **Did you use a generative AI model (e.g., ChatGPT) to create text or code for this assignment?**

# %% [markdown]
# NO

# %% [markdown]
# ---

# %% [markdown]
# ### **PART 1 - Problem Statement**
#
# Good Data Science (and data analysis more generally) depends on a clear understanding of the underlying problem/situation, the methods by which the data you are about to analyze are collected, and the situational context in which that data sits.  In fact, Data Science itself might be considered as <u>*computation with context*</u>.  To that end:
#
# **In order to provide context around the problem statement given in the Overview above, please read through the following <small>(and potentially some of the references therein)</small>:**
#
# <i>
#
# 1. [U.S. Lagging Far Behind Europe On Renewables, New Report Shows
# ](https://www.forbes.com/sites/davidrvetter/2020/03/09/us-lagging-far-behind-europe-on-renewables-new-report-shows/?sh=1d181fc133f4)
#
# 2. [International Energy Agency: Data & Statistics](https://www.iea.org/data-and-statistics/data-products) (the source of the data aggregated by the World Bank)
#
# 2. [A Critical Review of Sustainable Energy Policies for the Promotion of Renewable Energy Sources
# ](https://www.mdpi.com/2071-1050/12/12/5078)
#
# 3. [Analysis of renewable energies in European Union
# ](https://pdf.sciencedirectassets.com/271969/1-s2.0-S1364032115X00153/1-s2.0-S1364032115012319/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEIv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEv8hasIasGx0jWzNJf%2BM9eI44S0Sq1lFh4xNr3qest3AiEAt6rRb81hdPRQiIzwHvs3qm6fJeRPP%2BJkzHvEXY6B0NwqswUIZBAFGgwwNTkwMDM1NDY4NjUiDEkDr1zE8CO1XVz28SqQBds4LfJAnIiXgHkiI4lo2QjUHIUvCWqsENX%2BV3WgRA2bAkeA8tPs8PtVMi9WhSy16atx2j8AtXnMjY0jid8gqa22jWfrX1wtalvIbxmylhVj0CqABzRsKsFe1DJkaderXZcLlNbSrMMjUGVLN35YtAczv%2BYJyx6X0re93Hgtc8niIiPCXOaRx7lYMwRS5%2B752uideDE4GkhU%2BD2pF6ghEza1DTJMEOT4kKeTs7JSRVtsE9pQsqKB3tl6qwQA2WZaUgTOKKt3oyvZy063pZJsSExTPSW2S4WG0JaItRjqoy906yXJAaVeWefnMEgJqfdivA3NsUJF7ccoa4tVJy2RhCMHrZsfWLXifL%2F0BRmkgnWVwJwjnE%2Bb7dyEynZzMoB1hOQVio%2BdZOs%2Bk3aMe9CEfTG0jTQMp5d%2Bs0Y3%2BZcv59YcPv1XpFUORsqhtgljoEW%2BF1CgGjei6j3zODV2Eh2cHEnL7uSIFE30z5LCVwHEL4SVxhCd%2FLaJxcMj89s4zX4rTZrA%2F3Lyk0B9CpcPB0cX60ySSuErbhgERAl3DkVXQb8gfYJFdVXEdE6Yy7ChxVAMndR0jkz74U8sRxjfeeUk8BsnXwWMdl5yfpfFhSvcuAfovXizMnECMCb4zPZ0RmYuz3CcMyRR%2FyAj4DLNNh8xyJd11EpBh67v%2B%2BmO83creNGAIiflHqAKqJyOtscYKP8u1BvFTMfFHrEF%2BV5w75llziKtWjppgA4eJ9JKgKhSVmPiEPjYjm3kFL8J3xJKm8b2bZbWFEPqJcDi9%2BcdXYC3PZ1BDxaWVBV%2FNH8n%2FY%2F%2FmdG%2Bqf06MKznTpgQLgHJPNlgIAmRlL4hzhWLHhRHv0gR%2FbVvW%2BFUDRYkWahVWlaU53pTMNbl3acGOrEB%2FmxJ6PmddKqde728BLw%2BwQfnjBfNJnfvGVsxw22f6l2znrhMnqhr2ITG1xYAI%2FLOKj0Cd%2BFfa5CHeAtff69iHn4BTRt%2Fua4C3h45xn%2BkWnqMgcMVn3iadW69JsWS8i7SodDBrY5oInXqdhFhjEabp5lh4ez4%2B2OZFVQ7yJgRX%2FITERp%2FuRHJ%2FsViUIyqGEk7XCABSAd8YahlWTufXn08kwce6QjnkDe0TQJlsnenbIu7&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230905T190651Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTYQMY24RXF%2F20230905%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=7b4e23c6560220bd023da02eba04148f96603b1563313e8391038011591c90b3&hash=1fff5c8518679ae6a30f9a440ac0373a1c50577be5400c6ba8eaa9df386b7e0c&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S1364032115012319&tid=spdf-8db1c08a-0ccb-49d8-95f2-ac1380fc9a59&sid=a9562e2e6b6d7648f38bb0a6d56e8311e386gxrqa&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=0f105b51545f0d545356&rr=8020c0743b4f78d0&cc=us)
#
# 4. [Renewable energy is growing fast in the U.S., but fossil fuels still dominate](https://www.pewresearch.org/fact-tank/2020/01/15/renewable-energy-is-growing-fast-in-the-u-s-but-fossil-fuels-still-dominate/)
#
# </i>
#
# <small>* Note that, for this assignment, this section only requires that you briefly read through and browse these references.  Future assignments will involve identifying policy-relevant references specific to the Problem Statement and summarizing them for context.</small>

# %% [markdown]
# ### **PART 2 - Data Collection**

# %% [markdown]
# **Copy the link for the *Excel* file from [this World Bank Open Data](https://data.worldbank.org/indicator/EG.USE.COMM.CL.ZS?locations=US) site and put it into a variable called `fname` as a string.**

# %%
fname = "https://api.worldbank.org/v2/en/indicator/EG.USE.COMM.CL.ZS?downloadformat=excel"

# %% [markdown]
# **Load the file into a `pandas` DataFrame called `data` similarly to how we did in class, but with three minor differences:**
#
# 1. **use `pd.read_excel` instead of `pd.read_csv`,**
# 2. **set `skiprows=3`,**
# 3. **also set `sheet_name="Data"`.**
#
# The last two (`skiprows` and `sheet_name`) are called "keywords" in python and are additional inputs that can be given to the `pd.read_excel()` function$^\dagger$.
#
# <small>$^\dagger$ recall that "functions" in python are constructs that tell python to do things</small>

# %%
import pandas as pd

data = pd.read_excel(fname, skiprows=3, sheet_name="Data")

# %%
data
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# 1    Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# 2    Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# 3    Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# 4    Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# ..                                                 ...                ...
# 261  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# 262  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# 263  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# 264  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# 265  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
#
#      1960  1961  1962  1963  1964  1965  ...      2013      2014  2015  2016  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN   NaN   NaN
# 1     NaN   NaN   NaN   NaN   NaN   NaN  ...  2.763343  2.584831   NaN   NaN
# 2     NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN   NaN   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN  ...  0.814806  0.834197   NaN   NaN
# 4     NaN   NaN   NaN   NaN   NaN   NaN  ...  2.546607  2.548840   NaN   NaN
# ..    ...   ...   ...   ...   ...   ...  ...       ...       ...   ...   ...
# 261   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.383520  0.519176   NaN   NaN
# 262   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.000000       NaN   NaN   NaN
# 263   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.768740  2.664954   NaN   NaN
# 264   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.674833       NaN   NaN   NaN
# 265   NaN   NaN   NaN   NaN   NaN   NaN  ...  3.295843       NaN   NaN   NaN
#
#      2017  2018  2019  2020  2021  2022
# 0     NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...   ...   ...   ...
# 261   NaN   NaN   NaN   NaN   NaN   NaN
# 262   NaN   NaN   NaN   NaN   NaN   NaN
# 263   NaN   NaN   NaN   NaN   NaN   NaN
# 264   NaN   NaN   NaN   NaN   NaN   NaN
# 265   NaN   NaN   NaN   NaN   NaN   NaN
#
# [266 rows x 67 columns]

# %% [markdown]
# ### **PART 3 - Data Preparation**

# %% [markdown]
# **Sub-select only the columns with names that are years (i.e., "1960", "1961", ...) before 2016 and put the resulting DataFrame into a new DataFrame called `sub`.**

# %%
sub = data[data.columns[4:60]]

# %% [markdown]
# **Create a column called `"Country Name"` in `sub` that is the values from the `"Country Name"` column from `data`.**$^\dagger$
#
# <small>$^\dagger$ ignore the warning that you get, but make sure you print `sub` so that you can see that it worked.</small>

# %%
sub["Country Name"] = data[data.columns[0]]
sub
# Out:
# <ipython-input-35-ba3e08b6fd46>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub["Country Name"] = data[data.columns[0]]
#      1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 261   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 262   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 263   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 264   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 265   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#          2007      2008      2009      2010      2011      2012      2013  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1    2.393256  2.431857  2.420201  2.504935  2.624055  2.558147  2.763343
# 2         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3    0.799720  0.894148  0.857032  0.838698  0.853197  0.855089  0.814806
# 4    1.776957  2.145972  1.949433  2.250755  2.352302  2.017802  2.546607
# ..        ...       ...       ...       ...       ...       ...       ...
# 261  0.303804  0.242909  0.342893  0.439343  0.291907  0.273455  0.383520
# 262  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 263  2.222002  2.398508  2.426837  2.373676  2.643181  2.354826  2.768740
# 264  9.250263  8.126349  7.875824  8.135437  8.475090  9.718801  9.674833
# 265  5.688800  5.369195  4.968873  4.483218  3.807726  3.648776  3.295843
#
#          2014  2015                 Country Name
# 0         NaN   NaN                        Aruba
# 1    2.584831   NaN  Africa Eastern and Southern
# 2         NaN   NaN                  Afghanistan
# 3    0.834197   NaN   Africa Western and Central
# 4    2.548840   NaN                       Angola
# ..        ...   ...                          ...
# 261  0.519176   NaN                       Kosovo
# 262       NaN   NaN                  Yemen, Rep.
# 263  2.664954   NaN                 South Africa
# 264       NaN   NaN                       Zambia
# 265       NaN   NaN                     Zimbabwe
#
# [266 rows x 57 columns]

# %% [markdown]
# **Run the cell below (no need to figure out what it's doing, we will go over all of this syntax in time).**

# %%
# -- reformat the data
ae_yr = sub.set_index("Country Name").T.reset_index().rename(columns={"index":"year"}).astype(float)
ae_yr
# Out:
# Country Name    year  Aruba  Africa Eastern and Southern  Afghanistan  \
# 0             1960.0    NaN                          NaN          NaN
# 1             1961.0    NaN                          NaN          NaN
# 2             1962.0    NaN                          NaN          NaN
# 3             1963.0    NaN                          NaN          NaN
# 4             1964.0    NaN                          NaN          NaN
# 5             1965.0    NaN                          NaN          NaN
# 6             1966.0    NaN                          NaN          NaN
# 7             1967.0    NaN                          NaN          NaN
# 8             1968.0    NaN                          NaN          NaN
# 9             1969.0    NaN                          NaN          NaN
# 10            1970.0    NaN                          NaN          NaN
# 11            1971.0    NaN                     0.726261          NaN
# 12            1972.0    NaN                     1.057346          NaN
# 13            1973.0    NaN                     1.056614          NaN
# 14            1974.0    NaN                     1.365164          NaN
# 15            1975.0    NaN                     1.417021          NaN
# 16            1976.0    NaN                     1.528770          NaN
# 17            1977.0    NaN                     1.663894          NaN
# 18            1978.0    NaN                     1.558105          NaN
# 19            1979.0    NaN                     1.560023          NaN
# 20            1980.0    NaN                     1.393254          NaN
# 21            1981.0    NaN                     1.394037          NaN
# 22            1982.0    NaN                     1.317128          NaN
# 23            1983.0    NaN                     1.268408          NaN
# 24            1984.0    NaN                     1.802935          NaN
# 25            1985.0    NaN                     2.057478          NaN
# 26            1986.0    NaN                     2.700695          NaN
# 27            1987.0    NaN                     2.105050          NaN
# 28            1988.0    NaN                     2.799851          NaN
# 29            1989.0    NaN                     2.943618          NaN
# 30            1990.0    NaN                     2.081310          NaN
# 31            1991.0    NaN                     2.186884          NaN
# 32            1992.0    NaN                     2.233992          NaN
# 33            1993.0    NaN                     1.836533          NaN
# 34            1994.0    NaN                     2.100294          NaN
# 35            1995.0    NaN                     2.224634          NaN
# 36            1996.0    NaN                     2.292018          NaN
# 37            1997.0    NaN                     2.349575          NaN
# 38            1998.0    NaN                     2.451677          NaN
# 39            1999.0    NaN                     2.321523          NaN
# 40            2000.0    NaN                     2.459667          NaN
# 41            2001.0    NaN                     2.288112          NaN
# 42            2002.0    NaN                     2.509645          NaN
# 43            2003.0    NaN                     2.604896          NaN
# 44            2004.0    NaN                     2.593332          NaN
# 45            2005.0    NaN                     2.408646          NaN
# 46            2006.0    NaN                     2.403366          NaN
# 47            2007.0    NaN                     2.393256          NaN
# 48            2008.0    NaN                     2.431857          NaN
# 49            2009.0    NaN                     2.420201          NaN
# 50            2010.0    NaN                     2.504935          NaN
# 51            2011.0    NaN                     2.624055          NaN
# 52            2012.0    NaN                     2.558147          NaN
# 53            2013.0    NaN                     2.763343          NaN
# 54            2014.0    NaN                     2.584831          NaN
# 55            2015.0    NaN                          NaN          NaN
#
# Country Name  Africa Western and Central    Angola    Albania  Andorra  \
# 0                                    NaN       NaN        NaN      NaN
# 1                                    NaN       NaN        NaN      NaN
# 2                                    NaN       NaN        NaN      NaN
# 3                                    NaN       NaN        NaN      NaN
# 4                                    NaN       NaN        NaN      NaN
# 5                                    NaN       NaN        NaN      NaN
# 6                                    NaN       NaN        NaN      NaN
# 7                                    NaN       NaN        NaN      NaN
# 8                                    NaN       NaN        NaN      NaN
# 9                                    NaN       NaN        NaN      NaN
# 10                                   NaN       NaN        NaN      NaN
# 11                              1.084481  1.351166   3.504446      NaN
# 12                              1.119014  1.410646   3.986335      NaN
# 13                              1.214438  1.694730   5.532738      NaN
# 14                              1.291871  1.748593   6.123031      NaN
# 15                              1.337377  1.982570   6.919162      NaN
# 16                              1.384875  0.903806   7.459716      NaN
# 17                              1.353189  0.916739   8.148727      NaN
# 18                              1.115849  1.028038   7.956728      NaN
# 19                              1.413199  1.065822  10.263759      NaN
# 20                              1.458066  1.121397   8.259655      NaN
# 21                              1.481267  1.114046   9.727010      NaN
# 22                              1.428520  1.197734   9.985083      NaN
# 23                              0.993785  1.067446   9.675468      NaN
# 24                              0.929082  1.098590   7.964705      NaN
# 25                              1.231684  1.208085   6.741082      NaN
# 26                              1.411651  1.194329  11.986752      NaN
# 27                              1.347860  1.166168  10.134539      NaN
# 28                              1.441170  1.120664   8.669959      NaN
# 29                              1.504346  1.110309   9.147893      NaN
# 30                              1.143933  0.742242   4.676392      NaN
# 31                              1.213449  0.738678   5.399556      NaN
# 32                              1.200184  0.802166   8.468053      NaN
# 33                              1.209365  0.820624  10.012655      NaN
# 34                              1.139237  0.813644  10.686574      NaN
# 35                              1.240211  0.818385  12.311928      NaN
# 36                              1.225334  0.816589  16.025289      NaN
# 37                              1.167044  0.950384  14.372317      NaN
# 38                              0.915970  1.095975  13.875295      NaN
# 39                              1.008633  0.880335  20.236480      NaN
# 40                              1.039284  0.873405  19.677699      NaN
# 41                              0.983828  0.933956  18.295070      NaN
# 42                              0.970338  1.002053  17.936785      NaN
# 43                              0.862664  1.028346  18.781150      NaN
# 44                              0.931577  1.178593  20.682115      NaN
# 45                              0.924158  1.609625  20.332064      NaN
# 46                              0.837739  2.062969  14.006447      NaN
# 47                              0.799720  1.776957  15.549632      NaN
# 48                              0.894148  2.145972  19.268818      NaN
# 49                              0.857032  1.949433  21.875015      NaN
# 50                              0.838698  2.250755  23.282192      NaN
# 51                              0.853197  2.352302  22.109336      NaN
# 52                              0.855089  2.017802  25.419174      NaN
# 53                              0.814806  2.546607  26.068785      NaN
# 54                              0.834197  2.548840  24.548050      NaN
# 55                                   NaN       NaN        NaN      NaN
#
# Country Name  Arab World  United Arab Emirates  ...  Virgin Islands (U.S.)  \
# 0                    NaN                   NaN  ...                    NaN
# 1                    NaN                   NaN  ...                    NaN
# 2                    NaN                   NaN  ...                    NaN
# 3                    NaN                   NaN  ...                    NaN
# 4                    NaN                   NaN  ...                    NaN
# 5                    NaN                   NaN  ...                    NaN
# 6                    NaN                   NaN  ...                    NaN
# 7                    NaN                   NaN  ...                    NaN
# 8                    NaN                   NaN  ...                    NaN
# 9                    NaN                   NaN  ...                    NaN
# 10                   NaN                   NaN  ...                    NaN
# 11              1.399919              0.000000  ...                    NaN
# 12              1.423457              0.000000  ...                    NaN
# 13              1.240941              0.000000  ...                    NaN
# 14              1.387939              0.000000  ...                    NaN
# 15              1.372053              0.000000  ...                    NaN
# 16              1.442331              0.000000  ...                    NaN
# 17              1.507833              0.000000  ...                    NaN
# 18              1.386620              0.000000  ...                    NaN
# 19              1.244476              0.000000  ...                    NaN
# 20              1.111381              0.000000  ...                    NaN
# 21              0.970610              0.000000  ...                    NaN
# 22              0.874439              0.000000  ...                    NaN
# 23              0.750301              0.000000  ...                    NaN
# 24              0.759657              0.000000  ...                    NaN
# 25              0.693671              0.000000  ...                    NaN
# 26              0.660359              0.000000  ...                    NaN
# 27              0.689414              0.000000  ...                    NaN
# 28              0.635368              0.000000  ...                    NaN
# 29              0.642141              0.000000  ...                    NaN
# 30              0.597811              0.000000  ...                    NaN
# 31              0.527419              0.000000  ...                    NaN
# 32              0.460235              0.000000  ...                    NaN
# 33              0.432853              0.000000  ...                    NaN
# 34              0.424850              0.000000  ...                    NaN
# 35              0.409781              0.000000  ...                    NaN
# 36              0.443233              0.000000  ...                    NaN
# 37              0.442064              0.000000  ...                    NaN
# 38              0.442781              0.000000  ...                    NaN
# 39              0.465494              0.000000  ...                    NaN
# 40              0.424141              0.000000  ...                    NaN
# 41              0.428035              0.000000  ...                    NaN
# 42              0.362557              0.000000  ...                    NaN
# 43              0.396426              0.000000  ...                    NaN
# 44              0.390467              0.000000  ...                    NaN
# 45              0.445673              0.000000  ...                    NaN
# 46              0.423073              0.000000  ...                    NaN
# 47              0.423763              0.000000  ...                    NaN
# 48              0.350604              0.000000  ...                    NaN
# 49              0.358836              0.000000  ...                    NaN
# 50              0.434215              0.000000  ...                    NaN
# 51              0.416438              0.000000  ...                    NaN
# 52              0.396857              0.000000  ...                    NaN
# 53              0.446661              0.025763  ...                    NaN
# 54              0.414413              0.096907  ...                    NaN
# 55                   NaN                   NaN  ...                    NaN
#
# Country Name   Vietnam  Vanuatu      World  Samoa    Kosovo  Yemen, Rep.  \
# 0                  NaN      NaN   2.727828    NaN       NaN          NaN
# 1                  NaN      NaN   2.800560    NaN       NaN          NaN
# 2                  NaN      NaN   2.764664    NaN       NaN          NaN
# 3                  NaN      NaN   2.773203    NaN       NaN          NaN
# 4                  NaN      NaN   2.778784    NaN       NaN          NaN
# 5                  NaN      NaN   2.981818    NaN       NaN          NaN
# 6                  NaN      NaN   3.074811    NaN       NaN          NaN
# 7                  NaN      NaN   3.054320    NaN       NaN          NaN
# 8                  NaN      NaN   3.051865    NaN       NaN          NaN
# 9                  NaN      NaN   3.066423    NaN       NaN          NaN
# 10                 NaN      NaN   2.986153    NaN       NaN          NaN
# 11            0.399354      NaN   2.706012    NaN       NaN          0.0
# 12            0.271953      NaN   2.924087    NaN       NaN          0.0
# 13            0.258809      NaN   3.075137    NaN       NaN          0.0
# 14            0.275998      NaN   3.586211    NaN       NaN          0.0
# 15            0.309190      NaN   4.147384    NaN       NaN          0.0
# 16            0.383737      NaN   4.162020    NaN       NaN          0.0
# 17            0.397851      NaN   4.513245    NaN       NaN          0.0
# 18            0.517064      NaN   4.878371    NaN       NaN          0.0
# 19            0.624813      NaN   4.968432    NaN       NaN          0.0
# 20            0.889171      NaN   5.284380    NaN       NaN          0.0
# 21            0.889248      NaN   5.952853    NaN       NaN          0.0
# 22            0.888464      NaN   6.322327    NaN       NaN          0.0
# 23            0.674768      NaN   6.885394    NaN       NaN          0.0
# 24            0.871804      NaN   7.507469    NaN       NaN          0.0
# 25            0.795553      NaN   8.269710    NaN       NaN          0.0
# 26            0.723338      NaN   8.669029    NaN       NaN          0.0
# 27            0.672411      NaN   8.828671    NaN       NaN          0.0
# 28            0.862098      NaN   9.084805    NaN       NaN          0.0
# 29            1.890018      NaN   9.153488    NaN       NaN          0.0
# 30            1.841635      NaN   8.048779    NaN       NaN          0.0
# 31            2.144323      NaN   8.343299    NaN       NaN          0.0
# 32            2.348363      NaN   8.391454    NaN       NaN          0.0
# 33            2.455439      NaN   8.596767    NaN       NaN          0.0
# 34            2.926400      NaN   8.718204    NaN       NaN          0.0
# 35            3.178902      NaN   8.862558    NaN       NaN          0.0
# 36            3.527002      NaN   8.941590    NaN       NaN          0.0
# 37            3.219634      NaN   8.814975    NaN       NaN          0.0
# 38            2.938113      NaN   8.939041    NaN       NaN          0.0
# 39            3.598854      NaN   9.041372    NaN       NaN          0.0
# 40            3.673043      NaN   9.051321    NaN  0.230154          0.0
# 41            4.298490      NaN   9.055738    NaN  0.188229          0.0
# 42            3.931045      NaN   9.009325    NaN  0.189113          0.0
# 43            3.958397      NaN   8.697015    NaN  0.180853          0.0
# 44            3.369590      NaN   8.702728    NaN  0.358177          0.0
# 45            3.101582      NaN   8.628643    NaN  0.361696          0.0
# 46            3.695476      NaN   8.563774    NaN  0.338694          0.0
# 47            3.986847      NaN   8.265278    NaN  0.303804          0.0
# 48            4.247104      NaN   8.326465    NaN  0.242909          0.0
# 49            4.494720      NaN   8.415198    NaN  0.342893          0.0
# 50            3.690363      NaN   8.258011    NaN  0.439343          0.0
# 51            5.448965      NaN   7.938525    NaN  0.291907          0.0
# 52            6.802802      NaN   7.745533    NaN  0.273455          0.0
# 53            6.937204      NaN   7.913614    NaN  0.383520          0.0
# 54                 NaN      NaN   8.134738    NaN  0.519176          NaN
# 55                 NaN      NaN  13.354083    NaN       NaN          NaN
#
# Country Name  South Africa     Zambia  Zimbabwe
# 0                      NaN        NaN       NaN
# 1                      NaN        NaN       NaN
# 2                      NaN        NaN       NaN
# 3                      NaN        NaN       NaN
# 4                      NaN        NaN       NaN
# 5                      NaN        NaN       NaN
# 6                      NaN        NaN       NaN
# 7                      NaN        NaN       NaN
# 8                      NaN        NaN       NaN
# 9                      NaN        NaN       NaN
# 10                     NaN        NaN       NaN
# 11                0.021202   2.162930  3.834118
# 12                0.155265   6.945649  5.561152
# 13                0.172231   6.555072  5.110887
# 14                0.190889  11.910673  6.937724
# 15                0.178465  13.035683  7.661476
# 16                0.288950  13.636150  7.864818
# 17                0.293342  17.168298  8.545879
# 18                0.272351  15.495478  7.914351
# 19                0.158210  17.254445  8.403394
# 20                0.130482  17.100318  5.308975
# 21                0.197655  18.262311  5.062418
# 22                0.111711  18.572636  4.579407
# 23                0.064250  17.500810  4.390005
# 24                1.239526  16.752446  3.778181
# 25                1.665259  17.024938  3.316619
# 26                2.704741  16.286296  2.603888
# 27                1.872855  13.180698  1.114431
# 28                3.099105  12.912110  2.736711
# 29                3.368878  10.120450  3.234347
# 30                2.500761   9.279934  3.875576
# 31                2.657267   8.929271  2.799837
# 32                2.788040   9.082111  2.756891
# 33                2.001503   9.325439  1.979958
# 34                2.645497   9.390354  2.148914
# 35                2.877731   9.197682  2.341939
# 36                2.989905   9.212066  2.545436
# 37                3.172486   8.416752  2.654335
# 38                3.389518   7.803279  2.572375
# 39                3.109337   8.065355  3.590881
# 40                3.182112   8.259986  4.117328
# 41                2.623802   8.519045  3.304245
# 42                3.005342   8.811756  4.014183
# 43                2.859542   9.020697  5.774333
# 44                2.775105   9.305423  5.374427
# 45                2.380526   9.340733  4.880944
# 46                2.222276   9.574821  5.985829
# 47                2.222002   9.250263  5.688800
# 48                2.398508   8.126349  5.369195
# 49                2.426837   7.875824  4.968873
# 50                2.373676   8.135437  4.483218
# 51                2.643181   8.475090  3.807726
# 52                2.354826   9.718801  3.648776
# 53                2.768740   9.674833  3.295843
# 54                2.664954        NaN       NaN
# 55                     NaN        NaN       NaN
#
# [56 rows x 267 columns]

# %% [markdown]
# Notice now that you have a table in `ae_yr` that is very similar to the sea level rise table in class with one column that is the year, and the other columns are various geographic regions, the values of which are the % of energy use from alternative and nuclear sources.

# %% [markdown]
# **Make plots of the alternative and nuclear energy use percentage as a function of year for the United States and the European Union.**

# %%
data["Indicator Name"].unique()
# the data only contains the Alternative and nuclear energy as a percentage of total energy use.
# Out:
# array(['Alternative and nuclear energy (% of total energy use)'],
#       dtype=object)

# %%
ae_yr.plot("year", ["United States", "European Union"], ylabel="Alternative and Nuclear Energy\n[% of total energy use]")
# Out:
# <Axes: xlabel='year', ylabel='Alternative and Nuclear Energy\n[% of total energy use]'>

# %% [markdown]
# ### **PART 4 - "Machine Learning"**

# %% [markdown]
# **Fit a straight line to each of the above time series (one straight line for the US and one for the EU) using `np.polyfit` as we did in class.**

# %%
import numpy as np

params_US = np.polyfit(ae_yr["year"], ae_yr["United States"], 1)
params_EU = np.polyfit(ae_yr["year"], ae_yr["European Union"], 1)

# %%
model_US = params_US[0] * ae_yr['year'] + params_US[1]
model_EU = params_EU[0] * ae_yr['year'] + params_EU[1]

ae_yr["model_US"] = model_US
ae_yr["model_EU"] = model_EU

# %%
ae_yr.plot("year", ["United States", "European Union", "model_US", "model_EU"], ylabel="Alternative and Nuclear Energy\n[% of total energy use]")
# Out:
# <Axes: xlabel='year', ylabel='Alternative and Nuclear Energy\n[% of total energy use]'>

# %% [markdown]
# ### **PART 5 - Problem Solution**

# %% [markdown]
#  **Compare the rate of adoption of alternative and nuclear energy sources (in % per year) for the US and the EU.**

# %%
# n sets the precision for the round function.
n = 2

print(f"The rate of adoption of alternative and nuclear energy soruces for the Unites States is {round(params_US[0],n)} percent per year,\n" +
      f"while for the European Union it is {round(params_EU[0], n)} percent per year. The rate of adoption of the European Union is {round(params_EU[0]-params_US[0],n)}\n" +
      "percentage points higher than the Unites States' one")
# Out:
# The rate of adoption of alternative and nuclear energy soruces for the Unites States is 0.22 percent per year,
# while for the European Union it is 0.37 percent per year. The rate of adoption of the European Union is 0.15
# percentage points higher than the Unites States' one

# %% [markdown]
# **Is a straight line a "good" model in these cases?  Why or why not? <br> Is it a "better" model for one or the other?  Why or why not?**

# %% [markdown]
# The straight line might not be the best option in these cases, however it is a good enough illustration of the trend of adoption of alternative and nuclear energy of these two countries. I think that for the EU, other models might be more effective since there are some sudden changes of slope in the adoption. For example, around 1975 there was an increase in adoption with a large slope and around 1985 the slope decreased. That cannot be captured by the linear model that I fit to the data. In the case of the US, the model seems to work better because the rate of change remains more centred around the model. However, further analysis should be conducted to really assess which model is better and whether the models are good.
